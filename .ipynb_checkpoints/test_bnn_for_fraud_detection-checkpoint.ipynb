# %%
from Bayesian_Neural_Network import bayesian_neural_network
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(10120024)

# %%
input_layer = [1]
hidden_layers = [2]
output_layer = [1]

x_data = np.arange(-5, 5, 0.25) 
y_data = x_data

feature_data = y_data[:-1].reshape(-1, 1, 1)
target_data = y_data[1:].reshape(-1, 1, 1)

n_epochs = 10
learning_rate = 1e-6

initial_lr = 1e-6
end_lr = 1e-7
total_iters = 5
tuning_epochs = 10

# %%
from BNN_Learning_Rate_Tuning import bnn_learning_rate_tuning

bnn_lr_tuning = bnn_learning_rate_tuning(input_layer, hidden_layers, output_layer, feature_data, target_data, initial_lr, end_lr, total_iters, tuning_epochs)

# %%
bnn_lr_tuning.generate_all_decayed_learning_rate()
bnn_lr_tuning.learning_rate_tuning()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
fig.set_size_inches(20, 10)

plt.plot(-1 * bnn_lr_tuning.all_lr, bnn_lr_tuning.final_iter_mean_error)
